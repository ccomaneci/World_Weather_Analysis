# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 744

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          'Current Description': city_weather_description,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nelson bay
# Processing Record 2 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | pochutla
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | santa fe
# Processing Record 8 of Set 1 | kichmengskiy gorodok
# Processing Record 9 of Set 1 | krasnoselkup
# Processing Record 10 of Set 1 | avera
# Processing Record 11 of Set 1 | victoria
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | presidencia roque saenz pena
# Processing Record 16 of Set 1 | dong hoi
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | beringovskiy
# Processing Record 25 of Set 1 | cabedelo
# Processing Record 26 of Set 1 | neiafu
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | port macquarie
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | saint george
# Processing Record 31 of Set 1 | karachi
# Processing Record 32 of Set 1 | torbay
# Processing Record 33 of Set 1 | san antonio ilotenango
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | atar
# Processing Record 38 of Set 1 | airai
# Processing Record 39 of Set 1 | takapau
# Processing Record 40 of Set 1 | camiri
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 1 | cabo san lucas
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | barzas
# Processing Record 47 of Set 1 | guerrero negro
# Processing Record 48 of Set 1 | belaya gora
# Processing Record 49 of Set 1 | dianopolis
# City not found. Skipping...
# Processing Record 50 of Set 1 | sao filipe
# Processing Record 1 of Set 2 | hasaki
# Processing Record 2 of Set 2 | salisbury
# Processing Record 3 of Set 2 | ahuimanu
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | iqaluit
# Processing Record 7 of Set 2 | zheleznodorozhnyy
# Processing Record 8 of Set 2 | verin
# Processing Record 9 of Set 2 | kruisfontein
# Processing Record 10 of Set 2 | rassvet
# Processing Record 11 of Set 2 | pisco
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | iesolo
# Processing Record 14 of Set 2 | chokurdakh
# Processing Record 15 of Set 2 | nicolas bravo
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 2 | bairiki
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | esil
# Processing Record 22 of Set 2 | camacha
# Processing Record 23 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 2 | esperance
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | tautira
# Processing Record 27 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 2 | aklavik
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | mackay
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 2 | sibolga
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | okhotsk
# Processing Record 36 of Set 2 | vardo
# Processing Record 37 of Set 2 | port blair
# Processing Record 38 of Set 2 | ust-kut
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | port lincoln
# Processing Record 41 of Set 2 | sambava
# Processing Record 42 of Set 2 | north bend
# Processing Record 43 of Set 2 | provideniya
# Processing Record 44 of Set 2 | lima
# Processing Record 45 of Set 2 | da nang
# Processing Record 46 of Set 2 | bismarck
# Processing Record 47 of Set 2 | ribeira grande
# Processing Record 48 of Set 2 | mont-de-marsan
# Processing Record 49 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 2 | baringo
# Processing Record 1 of Set 3 | saldanha
# Processing Record 2 of Set 3 | dumas
# Processing Record 3 of Set 3 | tarazona
# Processing Record 4 of Set 3 | huanren
# Processing Record 5 of Set 3 | medford
# Processing Record 6 of Set 3 | norman wells
# Processing Record 7 of Set 3 | ancud
# Processing Record 8 of Set 3 | atbasar
# Processing Record 9 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 3 | mount isa
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | abalak
# Processing Record 13 of Set 3 | barrow
# Processing Record 14 of Set 3 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 3 | clyde river
# Processing Record 18 of Set 3 | omboue
# Processing Record 19 of Set 3 | dhidhdhoo
# Processing Record 20 of Set 3 | nanortalik
# Processing Record 21 of Set 3 | primorsk
# Processing Record 22 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 3 | mayskiy
# Processing Record 24 of Set 3 | urengoy
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 3 | bethel
# Processing Record 28 of Set 3 | whitecourt
# Processing Record 29 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 3 | flagstaff
# Processing Record 31 of Set 3 | finnsnes
# Processing Record 32 of Set 3 | siparia
# Processing Record 33 of Set 3 | jalu
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | cardiff
# Processing Record 36 of Set 3 | codrington
# Processing Record 37 of Set 3 | awbari
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | umba
# Processing Record 40 of Set 3 | tiksi
# Processing Record 41 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 3 | lata
# Processing Record 43 of Set 3 | georgetown
# Processing Record 44 of Set 3 | san patricio
# Processing Record 45 of Set 3 | havre-saint-pierre
# Processing Record 46 of Set 3 | tyret pervaya
# Processing Record 47 of Set 3 | hofn
# Processing Record 48 of Set 3 | marfino
# Processing Record 49 of Set 3 | rawah
# Processing Record 50 of Set 3 | samsun
# Processing Record 1 of Set 4 | itoman
# Processing Record 2 of Set 4 | atikokan
# Processing Record 3 of Set 4 | san quintin
# Processing Record 4 of Set 4 | tambo
# Processing Record 5 of Set 4 | yellowknife
# Processing Record 6 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 4 | upernavik
# Processing Record 8 of Set 4 | madang
# Processing Record 9 of Set 4 | matadi
# Processing Record 10 of Set 4 | lompoc
# Processing Record 11 of Set 4 | feijo
# Processing Record 12 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 4 | zhezkazgan
# Processing Record 14 of Set 4 | chicama
# Processing Record 15 of Set 4 | udupi
# Processing Record 16 of Set 4 | togur
# Processing Record 17 of Set 4 | peniche
# Processing Record 18 of Set 4 | najran
# Processing Record 19 of Set 4 | mar del plata
# Processing Record 20 of Set 4 | lebu
# Processing Record 21 of Set 4 | hithadhoo
# Processing Record 22 of Set 4 | rio gallegos
# Processing Record 23 of Set 4 | tromso
# Processing Record 24 of Set 4 | berlevag
# Processing Record 25 of Set 4 | juneau
# Processing Record 26 of Set 4 | tadine
# Processing Record 27 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 28 of Set 4 | moose factory
# Processing Record 29 of Set 4 | sarangani
# Processing Record 30 of Set 4 | karpogory
# Processing Record 31 of Set 4 | burnie
# Processing Record 32 of Set 4 | golden
# Processing Record 33 of Set 4 | castro
# Processing Record 34 of Set 4 | grand gaube
# Processing Record 35 of Set 4 | kysyl-syr
# Processing Record 36 of Set 4 | atambua
# Processing Record 37 of Set 4 | coracora
# Processing Record 38 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 39 of Set 4 | bonavista
# Processing Record 40 of Set 4 | conceicao do araguaia
# Processing Record 41 of Set 4 | pozo colorado
# Processing Record 42 of Set 4 | broome
# Processing Record 43 of Set 4 | ostrovnoy
# Processing Record 44 of Set 4 | portland
# Processing Record 45 of Set 4 | nyurba
# Processing Record 46 of Set 4 | owensboro
# Processing Record 47 of Set 4 | poum
# Processing Record 48 of Set 4 | cartagena
# Processing Record 49 of Set 4 | isangel
# Processing Record 50 of Set 4 | bintulu
# Processing Record 1 of Set 5 | ilhabela
# Processing Record 2 of Set 5 | chimbote
# Processing Record 3 of Set 5 | rawson
# Processing Record 4 of Set 5 | bone
# Processing Record 5 of Set 5 | caravelas
# Processing Record 6 of Set 5 | moussoro
# Processing Record 7 of Set 5 | geraldton
# Processing Record 8 of Set 5 | maamba
# Processing Record 9 of Set 5 | williamsburg
# Processing Record 10 of Set 5 | ballina
# Processing Record 11 of Set 5 | joconal
# Processing Record 12 of Set 5 | kamenka
# Processing Record 13 of Set 5 | husavik
# Processing Record 14 of Set 5 | sakakah
# Processing Record 15 of Set 5 | todos santos
# Processing Record 16 of Set 5 | paita
# Processing Record 17 of Set 5 | suicheng
# Processing Record 18 of Set 5 | finschhafen
# Processing Record 19 of Set 5 | kaura namoda
# Processing Record 20 of Set 5 | nalut
# Processing Record 21 of Set 5 | hovd
# Processing Record 22 of Set 5 | walvis bay
# Processing Record 23 of Set 5 | sarkand
# Processing Record 24 of Set 5 | kaitangata
# Processing Record 25 of Set 5 | ewo
# Processing Record 26 of Set 5 | kudahuvadhoo
# Processing Record 27 of Set 5 | ilulissat
# Processing Record 28 of Set 5 | kalmunai
# Processing Record 29 of Set 5 | nantucket
# Processing Record 30 of Set 5 | ucluelet
# Processing Record 31 of Set 5 | tuatapere
# Processing Record 32 of Set 5 | chuy
# Processing Record 33 of Set 5 | kavieng
# Processing Record 34 of Set 5 | coleraine
# Processing Record 35 of Set 5 | wageningen
# Processing Record 36 of Set 5 | road town
# Processing Record 37 of Set 5 | labrea
# Processing Record 38 of Set 5 | katete
# Processing Record 39 of Set 5 | alofi
# Processing Record 40 of Set 5 | terrace bay
# Processing Record 41 of Set 5 | tilichiki
# Processing Record 42 of Set 5 | bambous virieux
# Processing Record 43 of Set 5 | ternate
# Processing Record 44 of Set 5 | tasiilaq
# Processing Record 45 of Set 5 | teutonia
# Processing Record 46 of Set 5 | noumea
# Processing Record 47 of Set 5 | luau
# Processing Record 48 of Set 5 | sitio novo do tocantins
# Processing Record 49 of Set 5 | aden
# Processing Record 50 of Set 5 | kuala terengganu
# Processing Record 1 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 6 | maniitsoq
# Processing Record 3 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 6 | aksarka
# Processing Record 5 of Set 6 | rio bananal
# Processing Record 6 of Set 6 | methoni
# Processing Record 7 of Set 6 | colares
# Processing Record 8 of Set 6 | coihaique
# Processing Record 9 of Set 6 | arvika
# Processing Record 10 of Set 6 | mahebourg
# Processing Record 11 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 12 of Set 6 | garavuti
# Processing Record 13 of Set 6 | prokopyevsk
# Processing Record 14 of Set 6 | quchan
# Processing Record 15 of Set 6 | ati
# Processing Record 16 of Set 6 | san policarpo
# Processing Record 17 of Set 6 | george
# Processing Record 18 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 6 | turukhansk
# Processing Record 20 of Set 6 | touros
# Processing Record 21 of Set 6 | la ronge
# Processing Record 22 of Set 6 | lakes entrance
# Processing Record 23 of Set 6 | port-cartier
# Processing Record 24 of Set 6 | mariental
# Processing Record 25 of Set 6 | lorengau
# Processing Record 26 of Set 6 | kathmandu
# Processing Record 27 of Set 6 | faya
# Processing Record 28 of Set 6 | lagoa
# Processing Record 29 of Set 6 | jardim
# Processing Record 30 of Set 6 | gizo
# Processing Record 31 of Set 6 | liepaja
# Processing Record 32 of Set 6 | longyearbyen
# Processing Record 33 of Set 6 | hambantota
# Processing Record 34 of Set 6 | tengushevo
# Processing Record 35 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 6 | souillac
# Processing Record 37 of Set 6 | kamaishi
# Processing Record 38 of Set 6 | mandalgovi
# Processing Record 39 of Set 6 | moindou
# Processing Record 40 of Set 6 | adrar
# Processing Record 41 of Set 6 | san rafael
# Processing Record 42 of Set 6 | maracaju
# Processing Record 43 of Set 6 | sitka
# Processing Record 44 of Set 6 | kvarkeno
# Processing Record 45 of Set 6 | ponta do sol
# Processing Record 46 of Set 6 | lethem
# Processing Record 47 of Set 6 | dandong
# Processing Record 48 of Set 6 | garden city
# Processing Record 49 of Set 6 | bukama
# Processing Record 50 of Set 6 | praia
# Processing Record 1 of Set 7 | haines junction
# Processing Record 2 of Set 7 | omsukchan
# Processing Record 3 of Set 7 | ciudad bolivar
# Processing Record 4 of Set 7 | saskylakh
# Processing Record 5 of Set 7 | siyabuswa
# Processing Record 6 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 7 of Set 7 | rocha
# Processing Record 8 of Set 7 | san andres
# Processing Record 9 of Set 7 | loa janan
# Processing Record 10 of Set 7 | edd
# Processing Record 11 of Set 7 | flinders
# Processing Record 12 of Set 7 | pingzhuang
# Processing Record 13 of Set 7 | nemuro
# Processing Record 14 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 7 | teahupoo
# Processing Record 16 of Set 7 | smoky lake
# Processing Record 17 of Set 7 | bani walid
# Processing Record 18 of Set 7 | oranjestad
# Processing Record 19 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 7 | cidreira
# Processing Record 21 of Set 7 | liverpool
# Processing Record 22 of Set 7 | svetlyy
# Processing Record 23 of Set 7 | talnakh
# Processing Record 24 of Set 7 | alyangula
# Processing Record 25 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 7 | dingle
# Processing Record 27 of Set 7 | araouane
# Processing Record 28 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 29 of Set 7 | chapais
# Processing Record 30 of Set 7 | kirakira
# Processing Record 31 of Set 7 | gonzalez
# Processing Record 32 of Set 7 | sioux lookout
# Processing Record 33 of Set 7 | coquimbo
# Processing Record 34 of Set 7 | anapolis
# Processing Record 35 of Set 7 | seljord
# Processing Record 36 of Set 7 | blyth
# Processing Record 37 of Set 7 | deputatskiy
# Processing Record 38 of Set 7 | coahuayana
# Processing Record 39 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 7 | van buren
# Processing Record 41 of Set 7 | cap malheureux
# Processing Record 42 of Set 7 | mbandaka
# Processing Record 43 of Set 7 | lasa
# Processing Record 44 of Set 7 | formosa
# Processing Record 45 of Set 7 | istisu
# Processing Record 46 of Set 7 | antofagasta
# Processing Record 47 of Set 7 | goderich
# Processing Record 48 of Set 7 | zavyalovo
# Processing Record 49 of Set 7 | baruun-urt
# Processing Record 50 of Set 7 | tuktoyaktuk
# Processing Record 1 of Set 8 | rincon
# Processing Record 2 of Set 8 | ust-kulom
# Processing Record 3 of Set 8 | bantry
# Processing Record 4 of Set 8 | jaisalmer
# Processing Record 5 of Set 8 | achacachi
# Processing Record 6 of Set 8 | hauterive
# Processing Record 7 of Set 8 | santa maria
# Processing Record 8 of Set 8 | pastos bons
# Processing Record 9 of Set 8 | kropotkin
# Processing Record 10 of Set 8 | soyo
# Processing Record 11 of Set 8 | krasnyy chikoy
# Processing Record 12 of Set 8 | constitucion
# Processing Record 13 of Set 8 | henties bay
# Processing Record 14 of Set 8 | kloulklubed
# Processing Record 15 of Set 8 | lamu
# Processing Record 16 of Set 8 | rio grande
# Processing Record 17 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 8 | eenhana
# Processing Record 19 of Set 8 | colon
# Processing Record 20 of Set 8 | westport
# Processing Record 21 of Set 8 | bafq
# Processing Record 22 of Set 8 | skibbereen
# Processing Record 23 of Set 8 | tamandare
# Processing Record 24 of Set 8 | praya
# Processing Record 25 of Set 8 | igarka
# Processing Record 26 of Set 8 | shimoda
# Processing Record 27 of Set 8 | yerbogachen
# Processing Record 28 of Set 8 | kutum
# Processing Record 29 of Set 8 | san francisco
# Processing Record 30 of Set 8 | muros
# Processing Record 31 of Set 8 | saint anthony
# Processing Record 32 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 8 | buraydah
# Processing Record 34 of Set 8 | san cristobal
# Processing Record 35 of Set 8 | ambulu
# Processing Record 36 of Set 8 | mahanoro
# Processing Record 37 of Set 8 | havoysund
# Processing Record 38 of Set 8 | guantanamo
# Processing Record 39 of Set 8 | izhma
# Processing Record 40 of Set 8 | oistins
# Processing Record 41 of Set 8 | kipini
# Processing Record 42 of Set 8 | ketchikan
# Processing Record 43 of Set 8 | xam nua
# Processing Record 44 of Set 8 | port-gentil
# Processing Record 45 of Set 8 | fort-shevchenko
# Processing Record 46 of Set 8 | dolores
# Processing Record 47 of Set 8 | vila velha
# Processing Record 48 of Set 8 | leningradskiy
# Processing Record 49 of Set 8 | vao
# Processing Record 50 of Set 8 | tura
# Processing Record 1 of Set 9 | suchilquitongo
# City not found. Skipping...
# Processing Record 2 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 9 | tessalit
# Processing Record 4 of Set 9 | pangnirtung
# Processing Record 5 of Set 9 | ewa beach
# Processing Record 6 of Set 9 | calvinia
# Processing Record 7 of Set 9 | beloha
# Processing Record 8 of Set 9 | tezu
# Processing Record 9 of Set 9 | rosarito
# Processing Record 10 of Set 9 | bozeman
# Processing Record 11 of Set 9 | bure
# Processing Record 12 of Set 9 | winnemucca
# Processing Record 13 of Set 9 | byron bay
# Processing Record 14 of Set 9 | alice springs
# Processing Record 15 of Set 9 | lagunillas
# Processing Record 16 of Set 9 | kijang
# Processing Record 17 of Set 9 | salto
# Processing Record 18 of Set 9 | oranjemund
# Processing Record 19 of Set 9 | shablykino
# Processing Record 20 of Set 9 | warrnambool
# Processing Record 21 of Set 9 | lino lakes
# Processing Record 22 of Set 9 | miramar
# Processing Record 23 of Set 9 | college
# Processing Record 24 of Set 9 | yoichi
# Processing Record 25 of Set 9 | fallon
# Processing Record 26 of Set 9 | bundaberg
# Processing Record 27 of Set 9 | ayr
# Processing Record 28 of Set 9 | fort nelson
# Processing Record 29 of Set 9 | tandalti
# Processing Record 30 of Set 9 | sur
# Processing Record 31 of Set 9 | quatre cocos
# Processing Record 32 of Set 9 | olafsvik
# Processing Record 33 of Set 9 | nosy varika
# Processing Record 34 of Set 9 | port hardy
# Processing Record 35 of Set 9 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 36 of Set 9 | saurimo
# Processing Record 37 of Set 9 | nara
# Processing Record 38 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 39 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 9 | barao de melgaco
# Processing Record 41 of Set 9 | vaitape
# Processing Record 42 of Set 9 | mawlaik
# Processing Record 43 of Set 9 | bengkulu
# Processing Record 44 of Set 9 | moerai
# Processing Record 45 of Set 9 | ahtopol
# Processing Record 46 of Set 9 | susanville
# Processing Record 47 of Set 9 | hami
# Processing Record 48 of Set 9 | khandyga
# Processing Record 49 of Set 9 | verkhnevilyuysk
# Processing Record 50 of Set 9 | srednekolymsk
# Processing Record 1 of Set 10 | pontianak
# Processing Record 2 of Set 10 | sterling
# Processing Record 3 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 10 | adria
# Processing Record 5 of Set 10 | karistos
# City not found. Skipping...
# Processing Record 6 of Set 10 | karratha
# Processing Record 7 of Set 10 | tokmak
# Processing Record 8 of Set 10 | severo-kurilsk
# Processing Record 9 of Set 10 | gat
# Processing Record 10 of Set 10 | bongandanga
# Processing Record 11 of Set 10 | copiapo
# Processing Record 12 of Set 10 | indiaroba
# Processing Record 13 of Set 10 | alekseyevsk
# Processing Record 14 of Set 10 | port hedland
# Processing Record 15 of Set 10 | makungu
# Processing Record 16 of Set 10 | domoni
# Processing Record 17 of Set 10 | coldstream
# Processing Record 18 of Set 10 | deer lake
# Processing Record 19 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 20 of Set 10 | aldan
# Processing Record 21 of Set 10 | jiblah
# Processing Record 22 of Set 10 | broken hill
# Processing Record 23 of Set 10 | sistranda
# Processing Record 24 of Set 10 | venezuela
# Processing Record 25 of Set 10 | keetmanshoop
# Processing Record 26 of Set 10 | tsiroanomandidy
# Processing Record 27 of Set 10 | southbridge
# Processing Record 28 of Set 10 | mazatlan
# Processing Record 29 of Set 10 | mahon
# Processing Record 30 of Set 10 | porto empedocle
# Processing Record 31 of Set 10 | faanui
# Processing Record 32 of Set 10 | mount gambier
# Processing Record 33 of Set 10 | tskneti
# Processing Record 34 of Set 10 | puerto escondido
# Processing Record 35 of Set 10 | hamilton
# Processing Record 36 of Set 10 | san lawrenz
# Processing Record 37 of Set 10 | nkhotakota
# Processing Record 38 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 39 of Set 10 | bereda
# Processing Record 40 of Set 10 | ajdabiya
# Processing Record 41 of Set 10 | erzin
# Processing Record 42 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 10 | garowe
# Processing Record 44 of Set 10 | buala
# Processing Record 45 of Set 10 | ellensburg
# Processing Record 46 of Set 10 | pitimbu
# Processing Record 47 of Set 10 | pasighat
# Processing Record 48 of Set 10 | forestville
# Processing Record 49 of Set 10 | korla
# Processing Record 50 of Set 10 | jalingo
# Processing Record 1 of Set 11 | vung tau
# Processing Record 2 of Set 11 | teya
# Processing Record 3 of Set 11 | stabat
# Processing Record 4 of Set 11 | ixtapa
# Processing Record 5 of Set 11 | bonnyville
# Processing Record 6 of Set 11 | katakwi
# Processing Record 7 of Set 11 | taunsa
# Processing Record 8 of Set 11 | gore
# Processing Record 9 of Set 11 | skjervoy
# Processing Record 10 of Set 11 | maceio
# Processing Record 11 of Set 11 | okha
# Processing Record 12 of Set 11 | kimbe
# Processing Record 13 of Set 11 | ariano irpino
# Processing Record 14 of Set 11 | cameta
# Processing Record 15 of Set 11 | san felipe
# Processing Record 16 of Set 11 | dourbali
# Processing Record 17 of Set 11 | nome
# Processing Record 18 of Set 11 | mahibadhoo
# Processing Record 19 of Set 11 | esmeraldas
# Processing Record 20 of Set 11 | vikhorevka
# Processing Record 21 of Set 11 | vestmannaeyjar
# Processing Record 22 of Set 11 | moron
# Processing Record 23 of Set 11 | salalah
# Processing Record 24 of Set 11 | kawalu
# Processing Record 25 of Set 11 | kieta
# Processing Record 26 of Set 11 | dvinskoy
# Processing Record 27 of Set 11 | andover
# Processing Record 28 of Set 11 | voskevan
# Processing Record 29 of Set 11 | pinega
# Processing Record 30 of Set 11 | zhigansk
# Processing Record 31 of Set 11 | aybak
# City not found. Skipping...
# Processing Record 32 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 11 | the pas
# Processing Record 34 of Set 11 | naples
# Processing Record 35 of Set 11 | calabozo
# Processing Record 36 of Set 11 | biak
# Processing Record 37 of Set 11 | ipixuna
# Processing Record 38 of Set 11 | half moon bay
# Processing Record 39 of Set 11 | revda
# Processing Record 40 of Set 11 | black river
# Processing Record 41 of Set 11 | bambanglipuro
# Processing Record 42 of Set 11 | manjakandriana
# Processing Record 43 of Set 11 | asau
# Processing Record 44 of Set 11 | ca mau
# Processing Record 45 of Set 11 | northam
# Processing Record 46 of Set 11 | martigny
# Processing Record 47 of Set 11 | grindavik
# Processing Record 48 of Set 11 | unity
# Processing Record 49 of Set 11 | rodrigues alves
# Processing Record 50 of Set 11 | miles city
# Processing Record 1 of Set 12 | sedalia
# Processing Record 2 of Set 12 | sao joao do piaui
# Processing Record 3 of Set 12 | vanavara
# Processing Record 4 of Set 12 | yola
# Processing Record 5 of Set 12 | egvekinot
# Processing Record 6 of Set 12 | pietarsaari
# Processing Record 7 of Set 12 | lavrentiya
# Processing Record 8 of Set 12 | bilibino
# Processing Record 9 of Set 12 | salair
# Processing Record 10 of Set 12 | labuhan
# Processing Record 11 of Set 12 | roblin
# Processing Record 12 of Set 12 | kolondieba
# Processing Record 13 of Set 12 | la romana
# Processing Record 14 of Set 12 | mezen
# Processing Record 15 of Set 12 | micheweni
# Processing Record 16 of Set 12 | le port
# Processing Record 17 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 18 of Set 12 | mnogovershinnyy
# Processing Record 19 of Set 12 | brejo santo
# Processing Record 20 of Set 12 | fairbanks
# Processing Record 21 of Set 12 | preveza
# Processing Record 22 of Set 12 | sorland
# Processing Record 23 of Set 12 | palmer
# Processing Record 24 of Set 12 | takhatgarh
# Processing Record 25 of Set 12 | khristoforovo
# City not found. Skipping...
# Processing Record 26 of Set 12 | pouembout
# Processing Record 27 of Set 12 | bilma
# Processing Record 28 of Set 12 | totness
# Processing Record 29 of Set 12 | mountain home
# Processing Record 30 of Set 12 | taoudenni
# Processing Record 31 of Set 12 | sajanan
# Processing Record 32 of Set 12 | katsuura
# Processing Record 33 of Set 12 | dubai
# Processing Record 34 of Set 12 | socorro
# Processing Record 35 of Set 12 | russell
# Processing Record 36 of Set 12 | lobito
# Processing Record 37 of Set 12 | araguatins
# City not found. Skipping...
# Processing Record 38 of Set 12 | mae hong son
# Processing Record 39 of Set 12 | mouila
# Processing Record 40 of Set 12 | sapele
# Processing Record 41 of Set 12 | hervey bay
# Processing Record 42 of Set 12 | umm lajj
# Processing Record 43 of Set 12 | creel
# Processing Record 44 of Set 12 | mbeya
# Processing Record 45 of Set 12 | hit
# Processing Record 46 of Set 12 | te anau
# Processing Record 47 of Set 12 | kinablangan
# Processing Record 48 of Set 12 | altamira
# Processing Record 49 of Set 12 | tral
# Processing Record 50 of Set 12 | prince rupert
# Processing Record 1 of Set 13 | panguna
# Processing Record 2 of Set 13 | pingdingshan
# Processing Record 3 of Set 13 | bahia honda
# Processing Record 4 of Set 13 | giyon
# Processing Record 5 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 6 of Set 13 | qasigiannguit
# Processing Record 7 of Set 13 | hualmay
# Processing Record 8 of Set 13 | marawi
# Processing Record 9 of Set 13 | bara
# Processing Record 10 of Set 13 | vanimo
# Processing Record 11 of Set 13 | inhambane
# Processing Record 12 of Set 13 | dudinka
# Processing Record 13 of Set 13 | kaseda
# Processing Record 14 of Set 13 | narsaq
# Processing Record 15 of Set 13 | vostok
# Processing Record 16 of Set 13 | fereydunshahr
# Processing Record 17 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 18 of Set 13 | laguna
# Processing Record 19 of Set 13 | kristiinankaupunki
# Processing Record 20 of Set 13 | inzhavino
# Processing Record 21 of Set 13 | burkhala
# City not found. Skipping...
# Processing Record 22 of Set 13 | sinnamary
# Processing Record 23 of Set 13 | akyab
# Processing Record 24 of Set 13 | vegreville
# Processing Record 25 of Set 13 | morro bay
# Processing Record 26 of Set 13 | pacific grove
# Processing Record 27 of Set 13 | zhanaozen
# Processing Record 28 of Set 13 | zainsk
# Processing Record 29 of Set 13 | kletskaya
# Processing Record 30 of Set 13 | mayo
# Processing Record 31 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 32 of Set 13 | toucheng
# Processing Record 33 of Set 13 | ocean city
# Processing Record 34 of Set 13 | soe
# Processing Record 35 of Set 13 | tamiahua
# Processing Record 36 of Set 13 | suntar
# Processing Record 37 of Set 13 | cayenne
# Processing Record 38 of Set 13 | necochea
# Processing Record 39 of Set 13 | barcelona
# Processing Record 40 of Set 13 | yar-sale
# Processing Record 41 of Set 13 | barranca
# Processing Record 42 of Set 13 | bojaya
# City not found. Skipping...
# Processing Record 43 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 13 | tomra
# Processing Record 45 of Set 13 | roebourne
# Processing Record 46 of Set 13 | sisimiut
# Processing Record 47 of Set 13 | manakara
# Processing Record 48 of Set 13 | madimba
# Processing Record 49 of Set 13 | jibuti
# Processing Record 50 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 14 | namibe
# Processing Record 2 of Set 14 | alamosa
# Processing Record 3 of Set 14 | novyy karachay
# Processing Record 4 of Set 14 | batagay
# Processing Record 5 of Set 14 | shenjiamen
# Processing Record 6 of Set 14 | lenina
# Processing Record 7 of Set 14 | luderitz
# Processing Record 8 of Set 14 | ban phai
# Processing Record 9 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 10 of Set 14 | phon
# Processing Record 11 of Set 14 | obihiro
# Processing Record 12 of Set 14 | gobabis
# Processing Record 13 of Set 14 | san ignacio
# Processing Record 14 of Set 14 | san jose
# Processing Record 15 of Set 14 | milingimbi
# City not found. Skipping...
# Processing Record 16 of Set 14 | jining
# Processing Record 17 of Set 14 | ubinskoye
# Processing Record 18 of Set 14 | pukhrayan
# Processing Record 19 of Set 14 | calipan
# Processing Record 20 of Set 14 | dongsheng
# Processing Record 21 of Set 14 | vestmanna
# Processing Record 22 of Set 14 | sol-iletsk
# Processing Record 23 of Set 14 | balikpapan
# Processing Record 24 of Set 14 | keti bandar
# Processing Record 25 of Set 14 | kunya
# Processing Record 26 of Set 14 | ponta delgada
# Processing Record 27 of Set 14 | dickinson
# Processing Record 28 of Set 14 | santa marta
# Processing Record 29 of Set 14 | bauska
# Processing Record 30 of Set 14 | verkh-usugli
# Processing Record 31 of Set 14 | onalaska
# Processing Record 32 of Set 14 | iquique
# Processing Record 33 of Set 14 | katobu
# Processing Record 34 of Set 14 | meteti
# Processing Record 35 of Set 14 | fez
# Processing Record 36 of Set 14 | makaleng
# Processing Record 37 of Set 14 | meulaboh
# Processing Record 38 of Set 14 | kirillov
# Processing Record 39 of Set 14 | aitape
# Processing Record 40 of Set 14 | olovyannaya
# Processing Record 41 of Set 14 | ahipara
# Processing Record 42 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 14 | port moresby
# Processing Record 44 of Set 14 | calamar
# Processing Record 45 of Set 14 | serowe
# Processing Record 46 of Set 14 | sao jose da coroa grande
# Processing Record 47 of Set 14 | natal
# Processing Record 48 of Set 14 | naze
# Processing Record 49 of Set 14 | lhokseumawe
# Processing Record 50 of Set 14 | mhlume
# Processing Record 1 of Set 15 | phan thiet
# Processing Record 2 of Set 15 | elliot lake
# Processing Record 3 of Set 15 | batemans bay
# Processing Record 4 of Set 15 | luwuk
# Processing Record 5 of Set 15 | tabory
# Processing Record 6 of Set 15 | saint-joseph
# Processing Record 7 of Set 15 | bonthe
# Processing Record 8 of Set 15 | koumac
# Processing Record 9 of Set 15 | hobyo
# Processing Record 10 of Set 15 | cruz alta
# Processing Record 11 of Set 15 | tual
# Processing Record 12 of Set 15 | belmonte
# Processing Record 13 of Set 15 | gondanglegi
# Processing Record 14 of Set 15 | itarema
# Processing Record 15 of Set 15 | ust-maya
# Processing Record 16 of Set 15 | liku
# Processing Record 17 of Set 15 | dolinsk
# Processing Record 18 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 15 | san carlos de bariloche
# Processing Record 20 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 21 of Set 15 | marystown
# Processing Record 22 of Set 15 | sao joao da barra
# Processing Record 23 of Set 15 | bud
# Processing Record 24 of Set 15 | pekalongan
# Processing Record 25 of Set 15 | armacao de pera
# Processing Record 26 of Set 15 | inirida
# Processing Record 27 of Set 15 | fukue
# Processing Record 28 of Set 15 | spearfish
# Processing Record 29 of Set 15 | kharela
# Processing Record 30 of Set 15 | carlsbad
# Processing Record 31 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 15 | merzifon
# Processing Record 33 of Set 15 | roma
# Processing Record 34 of Set 15 | makung
# City not found. Skipping...
# Processing Record 35 of Set 15 | chapeco
# Processing Record 36 of Set 15 | santa cruz
# Processing Record 37 of Set 15 | budogoshch
# Processing Record 38 of Set 15 | namatanai
# Processing Record 39 of Set 15 | inta
# Processing Record 40 of Set 15 | ukiah
# Processing Record 41 of Set 15 | kasempa
# Processing Record 42 of Set 15 | williston
# Processing Record 43 of Set 15 | molina
# Processing Record 44 of Set 15 | kaeo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 681

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Nelson Bay -32.7167  152.1500     70.00        92         100
# 1                 Vaini -21.2000 -175.2000     74.26        80          71
# 2        Port Elizabeth -33.9180   25.5701     57.49        94          75
# 3              Pochutla  15.7432  -96.4661     76.82        92         100
# 4                Atuona  -9.8000 -139.0333     77.14        68           4
# 5              Santa Fe -31.6333  -60.7000     64.02        91          33
# 6  Kichmengskiy Gorodok  59.9816   45.7854     33.64        79         100
# 7          Krasnoselkup  65.7000   82.4667     36.43        95         100
# 8                 Avera  33.1940  -82.5271     40.91        40           2
# 9              Victoria  22.2855  114.1577     86.97        63          35
#
#    Wind Speed Country Current Description                 Date
# 0        4.00      AU       moderate rain  2022-10-21 04:27:50
# 1       22.03      TO          light rain  2022-10-21 04:27:50
# 2        2.30      ZA       broken clouds  2022-10-21 04:27:50
# 3        3.74      MX     overcast clouds  2022-10-21 04:27:51
# 4       16.73      PF           clear sky  2022-10-21 04:27:51
# 5        4.00      AR          light rain  2022-10-21 04:26:23
# 6       10.80      RU     overcast clouds  2022-10-21 04:27:51
# 7       14.61      RU     overcast clouds  2022-10-21 04:24:14
# 8        6.11      US           clear sky  2022-10-21 04:27:52
# 9        5.99      HK    scattered clouds  2022-10-21 04:24:34

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df.loc[:,["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df.loc[:,["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]

# Display sample data
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Nelson Bay      AU -32.7167  152.1500     70.00        92
# 1             Vaini      TO -21.2000 -175.2000     74.26        80
# 2    Port Elizabeth      ZA -33.9180   25.5701     57.49        94
# 3          Pochutla      MX  15.7432  -96.4661     76.82        92
# 4            Atuona      PF  -9.8000 -139.0333     77.14        68
# ..              ...     ...      ...       ...       ...       ...
# 676           Ukiah      US  39.1502 -123.2078     72.64        50
# 677         Kasempa      ZM -13.4584   25.8338     71.31        47
# 678       Williston      US  48.1470 -103.6180     56.32        51
# 679          Molina      CL -35.1167  -71.2833     56.93        72
# 680            Kaeo      NZ -35.1000  173.7833     66.33        69
#
#      Cloudiness  Wind Speed Current Description
# 0           100        4.00       moderate rain
# 1            71       22.03          light rain
# 2            75        2.30       broken clouds
# 3           100        3.74     overcast clouds
# 4             4       16.73           clear sky
# ..          ...         ...                 ...
# 676           0        1.01           clear sky
# 677          82        9.24       broken clouds
# 678         100        7.00     overcast clouds
# 679          93        5.75     overcast clouds
# 680          68        3.22       broken clouds
#
# [681 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City")
