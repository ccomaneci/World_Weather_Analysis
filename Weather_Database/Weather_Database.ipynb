# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 735

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          'Current Description': city_weather_description,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | haines junction
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | maykain
# City not found. Skipping...
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | codrington
# Processing Record 10 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 1 | poum
# Processing Record 12 of Set 1 | sao joao da barra
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | trofors
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | colac
# Processing Record 18 of Set 1 | batticaloa
# Processing Record 19 of Set 1 | alora
# Processing Record 20 of Set 1 | nizhnevartovsk
# Processing Record 21 of Set 1 | soller
# Processing Record 22 of Set 1 | svetlogorsk
# Processing Record 23 of Set 1 | dingle
# Processing Record 24 of Set 1 | baykit
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | grindavik
# Processing Record 28 of Set 1 | luanda
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | gayeri
# Processing Record 32 of Set 1 | bozoum
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | requena
# Processing Record 37 of Set 1 | bjornevatn
# Processing Record 38 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 1 | fortuna
# Processing Record 40 of Set 1 | san patricio
# Processing Record 41 of Set 1 | grand gaube
# Processing Record 42 of Set 1 | lagoa
# Processing Record 43 of Set 1 | provideniya
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | hasaki
# Processing Record 46 of Set 1 | farafangana
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | srednekolymsk
# Processing Record 49 of Set 1 | luderitz
# Processing Record 50 of Set 1 | ponta do sol
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | meulaboh
# Processing Record 3 of Set 2 | mandera
# Processing Record 4 of Set 2 | tiksi
# Processing Record 5 of Set 2 | lompoc
# Processing Record 6 of Set 2 | sinnamary
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | nome
# Processing Record 9 of Set 2 | kijang
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | semporna
# Processing Record 12 of Set 2 | larsnes
# Processing Record 13 of Set 2 | bereda
# Processing Record 14 of Set 2 | sotouboua
# Processing Record 15 of Set 2 | klaksvik
# Processing Record 16 of Set 2 | coruripe
# Processing Record 17 of Set 2 | peniche
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | pemangkat
# Processing Record 20 of Set 2 | mogadishu
# Processing Record 21 of Set 2 | namwala
# Processing Record 22 of Set 2 | manzanillo
# Processing Record 23 of Set 2 | saint george
# Processing Record 24 of Set 2 | rikitea
# Processing Record 25 of Set 2 | zeya
# Processing Record 26 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 27 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 2 | busselton
# Processing Record 29 of Set 2 | sungaipenuh
# Processing Record 30 of Set 2 | makaha
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | keetmanshoop
# Processing Record 35 of Set 2 | menomonie
# Processing Record 36 of Set 2 | vitimskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | bella union
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | mitu
# Processing Record 40 of Set 2 | inirida
# Processing Record 41 of Set 2 | chuy
# Processing Record 42 of Set 2 | albany
# Processing Record 43 of Set 2 | zhangjiakou
# Processing Record 44 of Set 2 | nhulunbuy
# Processing Record 45 of Set 2 | atar
# Processing Record 46 of Set 2 | bambous virieux
# Processing Record 47 of Set 2 | sangar
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | tura
# Processing Record 1 of Set 3 | rumphi
# Processing Record 2 of Set 3 | tanout
# Processing Record 3 of Set 3 | vao
# Processing Record 4 of Set 3 | ilulissat
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 3 | phuket
# Processing Record 9 of Set 3 | sola
# Processing Record 10 of Set 3 | longyearbyen
# Processing Record 11 of Set 3 | nerang
# Processing Record 12 of Set 3 | barrow
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | cerrito
# Processing Record 15 of Set 3 | hithadhoo
# Processing Record 16 of Set 3 | rocha
# Processing Record 17 of Set 3 | sao filipe
# Processing Record 18 of Set 3 | tasiilaq
# Processing Record 19 of Set 3 | astorga
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | ryotsu
# Processing Record 22 of Set 3 | la macarena
# Processing Record 23 of Set 3 | aklavik
# Processing Record 24 of Set 3 | acarau
# Processing Record 25 of Set 3 | guerrero negro
# Processing Record 26 of Set 3 | staryy nadym
# Processing Record 27 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 3 | curillo
# Processing Record 29 of Set 3 | vila velha
# Processing Record 30 of Set 3 | la asuncion
# Processing Record 31 of Set 3 | hambantota
# Processing Record 32 of Set 3 | port alfred
# Processing Record 33 of Set 3 | cabo san lucas
# Processing Record 34 of Set 3 | te anau
# Processing Record 35 of Set 3 | sioux lookout
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | sisimiut
# Processing Record 38 of Set 3 | dikson
# Processing Record 39 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 3 | inongo
# Processing Record 41 of Set 3 | mount gambier
# Processing Record 42 of Set 3 | leningradskiy
# Processing Record 43 of Set 3 | wiwili
# Processing Record 44 of Set 3 | buchanan
# Processing Record 45 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 3 | kyra
# Processing Record 47 of Set 3 | oranjemund
# Processing Record 48 of Set 3 | jamestown
# Processing Record 49 of Set 3 | fairbanks
# Processing Record 50 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 4 | touros
# Processing Record 2 of Set 4 | isangel
# Processing Record 3 of Set 4 | port hardy
# Processing Record 4 of Set 4 | norman wells
# Processing Record 5 of Set 4 | danville
# Processing Record 6 of Set 4 | ozernovskiy
# Processing Record 7 of Set 4 | new norfolk
# Processing Record 8 of Set 4 | fort nelson
# Processing Record 9 of Set 4 | hamilton
# Processing Record 10 of Set 4 | nongstoin
# Processing Record 11 of Set 4 | uni
# Processing Record 12 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 4 | saldanha
# Processing Record 14 of Set 4 | ho
# City not found. Skipping...
# Processing Record 15 of Set 4 | shimoda
# Processing Record 16 of Set 4 | grand forks
# Processing Record 17 of Set 4 | thompson
# Processing Record 18 of Set 4 | dauriya
# Processing Record 19 of Set 4 | kindersley
# Processing Record 20 of Set 4 | kautokeino
# Processing Record 21 of Set 4 | chokurdakh
# Processing Record 22 of Set 4 | grand-bourg
# Processing Record 23 of Set 4 | seymchan
# Processing Record 24 of Set 4 | bintulu
# Processing Record 25 of Set 4 | mongu
# Processing Record 26 of Set 4 | nijar
# Processing Record 27 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 28 of Set 4 | bluff
# Processing Record 29 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 4 | sterling
# Processing Record 33 of Set 4 | maralal
# Processing Record 34 of Set 4 | husavik
# Processing Record 35 of Set 4 | walvis bay
# Processing Record 36 of Set 4 | kaitangata
# Processing Record 37 of Set 4 | phan thiet
# Processing Record 38 of Set 4 | constitucion
# Processing Record 39 of Set 4 | lianzhou
# Processing Record 40 of Set 4 | yellowknife
# Processing Record 41 of Set 4 | palmer
# Processing Record 42 of Set 4 | wakkanai
# Processing Record 43 of Set 4 | whittlesea
# Processing Record 44 of Set 4 | sitka
# Processing Record 45 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 4 | tres arroyos
# Processing Record 47 of Set 4 | cabo rojo
# Processing Record 48 of Set 4 | troitskoye
# Processing Record 49 of Set 4 | yulara
# Processing Record 50 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 1 of Set 5 | mikhaylovka
# Processing Record 2 of Set 5 | lufilufi
# Processing Record 3 of Set 5 | esperance
# Processing Record 4 of Set 5 | immokalee
# Processing Record 5 of Set 5 | champerico
# Processing Record 6 of Set 5 | saint-philippe
# Processing Record 7 of Set 5 | tuatapere
# Processing Record 8 of Set 5 | arti
# Processing Record 9 of Set 5 | sao francisco do sul
# Processing Record 10 of Set 5 | mildura
# Processing Record 11 of Set 5 | nikolskoye
# Processing Record 12 of Set 5 | sorland
# Processing Record 13 of Set 5 | saint-pierre
# Processing Record 14 of Set 5 | ouallam
# Processing Record 15 of Set 5 | meiringen
# Processing Record 16 of Set 5 | ngorongoro
# Processing Record 17 of Set 5 | mizpe ramon
# City not found. Skipping...
# Processing Record 18 of Set 5 | howard springs
# Processing Record 19 of Set 5 | faanui
# Processing Record 20 of Set 5 | yarada
# Processing Record 21 of Set 5 | moron
# Processing Record 22 of Set 5 | el torno
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | seddon
# Processing Record 25 of Set 5 | bredasdorp
# Processing Record 26 of Set 5 | henties bay
# Processing Record 27 of Set 5 | show low
# Processing Record 28 of Set 5 | unhel
# Processing Record 29 of Set 5 | shahpur
# Processing Record 30 of Set 5 | bilma
# Processing Record 31 of Set 5 | lakes entrance
# Processing Record 32 of Set 5 | sechura
# Processing Record 33 of Set 5 | pevek
# Processing Record 34 of Set 5 | cayeli
# Processing Record 35 of Set 5 | warrington
# Processing Record 36 of Set 5 | nanortalik
# Processing Record 37 of Set 5 | clyde river
# Processing Record 38 of Set 5 | castro
# Processing Record 39 of Set 5 | yelizovo
# Processing Record 40 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 5 | inhambane
# Processing Record 42 of Set 5 | bethel
# Processing Record 43 of Set 5 | ramapuram
# Processing Record 44 of Set 5 | northam
# Processing Record 45 of Set 5 | saskylakh
# Processing Record 46 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 5 | malhador
# Processing Record 48 of Set 5 | araouane
# Processing Record 49 of Set 5 | kodinsk
# Processing Record 50 of Set 5 | sao gabriel da cachoeira
# Processing Record 1 of Set 6 | ostrovnoy
# Processing Record 2 of Set 6 | altea
# Processing Record 3 of Set 6 | bengkulu
# Processing Record 4 of Set 6 | sainte-anne-des-monts
# Processing Record 5 of Set 6 | marsa matruh
# Processing Record 6 of Set 6 | valparaiso
# Processing Record 7 of Set 6 | baker city
# Processing Record 8 of Set 6 | urambo
# Processing Record 9 of Set 6 | east london
# Processing Record 10 of Set 6 | kayasula
# Processing Record 11 of Set 6 | buritis
# Processing Record 12 of Set 6 | iranshahr
# Processing Record 13 of Set 6 | ternate
# Processing Record 14 of Set 6 | alamos
# Processing Record 15 of Set 6 | airai
# Processing Record 16 of Set 6 | belaya gora
# Processing Record 17 of Set 6 | izhma
# Processing Record 18 of Set 6 | palasa
# Processing Record 19 of Set 6 | richards bay
# Processing Record 20 of Set 6 | beysehir
# Processing Record 21 of Set 6 | nizhniy tagil-39
# City not found. Skipping...
# Processing Record 22 of Set 6 | luwuk
# Processing Record 23 of Set 6 | saint-georges
# Processing Record 24 of Set 6 | hofn
# Processing Record 25 of Set 6 | fare
# Processing Record 26 of Set 6 | naron
# Processing Record 27 of Set 6 | kupang
# Processing Record 28 of Set 6 | labuhan
# Processing Record 29 of Set 6 | nuuk
# Processing Record 30 of Set 6 | adrar
# Processing Record 31 of Set 6 | anadyr
# Processing Record 32 of Set 6 | margate
# Processing Record 33 of Set 6 | katsuura
# Processing Record 34 of Set 6 | lorengau
# Processing Record 35 of Set 6 | lyuban
# Processing Record 36 of Set 6 | broome
# Processing Record 37 of Set 6 | abong mbang
# Processing Record 38 of Set 6 | susah
# City not found. Skipping...
# Processing Record 39 of Set 6 | masallatah
# Processing Record 40 of Set 6 | necochea
# Processing Record 41 of Set 6 | yinchuan
# Processing Record 42 of Set 6 | tarakan
# Processing Record 43 of Set 6 | boyuibe
# Processing Record 44 of Set 6 | malanje
# Processing Record 45 of Set 6 | namibe
# Processing Record 46 of Set 6 | vardo
# Processing Record 47 of Set 6 | krasnoselkup
# Processing Record 48 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 49 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 6 | laguna
# Processing Record 1 of Set 7 | keti bandar
# Processing Record 2 of Set 7 | petro-slavyanka
# Processing Record 3 of Set 7 | saint anthony
# Processing Record 4 of Set 7 | sao jose da coroa grande
# Processing Record 5 of Set 7 | elko
# Processing Record 6 of Set 7 | hami
# Processing Record 7 of Set 7 | tigil
# Processing Record 8 of Set 7 | arman
# Processing Record 9 of Set 7 | athabasca
# Processing Record 10 of Set 7 | fuglebjerg
# Processing Record 11 of Set 7 | tomatlan
# Processing Record 12 of Set 7 | yantal
# Processing Record 13 of Set 7 | cockburn town
# Processing Record 14 of Set 7 | dwarka
# Processing Record 15 of Set 7 | barra patuca
# Processing Record 16 of Set 7 | nyeri
# Processing Record 17 of Set 7 | lazaro cardenas
# Processing Record 18 of Set 7 | rameswaram
# Processing Record 19 of Set 7 | cordoba
# Processing Record 20 of Set 7 | kyzyl-suu
# Processing Record 21 of Set 7 | yaroslavskiy
# Processing Record 22 of Set 7 | erenhot
# Processing Record 23 of Set 7 | port lincoln
# Processing Record 24 of Set 7 | bathsheba
# Processing Record 25 of Set 7 | kastamonu
# Processing Record 26 of Set 7 | qaqortoq
# Processing Record 27 of Set 7 | alofi
# Processing Record 28 of Set 7 | san cristobal
# Processing Record 29 of Set 7 | bandarbeyla
# Processing Record 30 of Set 7 | skjervoy
# Processing Record 31 of Set 7 | benguela
# Processing Record 32 of Set 7 | geraldton
# Processing Record 33 of Set 7 | itoman
# Processing Record 34 of Set 7 | mier
# Processing Record 35 of Set 7 | arrifes
# Processing Record 36 of Set 7 | gillette
# Processing Record 37 of Set 7 | celestun
# Processing Record 38 of Set 7 | kavaratti
# Processing Record 39 of Set 7 | gemena
# Processing Record 40 of Set 7 | bahia blanca
# Processing Record 41 of Set 7 | libin
# Processing Record 42 of Set 7 | raga
# Processing Record 43 of Set 7 | rassvet
# Processing Record 44 of Set 7 | hokitika
# Processing Record 45 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 46 of Set 7 | coihaique
# Processing Record 47 of Set 7 | vaitape
# Processing Record 48 of Set 7 | kutum
# Processing Record 49 of Set 7 | vila franca do campo
# Processing Record 50 of Set 7 | olinda
# Processing Record 1 of Set 8 | komsomolskiy
# Processing Record 2 of Set 8 | awbari
# Processing Record 3 of Set 8 | miraflores
# Processing Record 4 of Set 8 | nouakchott
# Processing Record 5 of Set 8 | jacareacanga
# Processing Record 6 of Set 8 | nauta
# Processing Record 7 of Set 8 | funadhoo
# Processing Record 8 of Set 8 | chumikan
# Processing Record 9 of Set 8 | jutai
# Processing Record 10 of Set 8 | tateyama
# Processing Record 11 of Set 8 | vestmannaeyjar
# Processing Record 12 of Set 8 | akureyri
# Processing Record 13 of Set 8 | gombong
# Processing Record 14 of Set 8 | kununurra
# Processing Record 15 of Set 8 | amga
# Processing Record 16 of Set 8 | panjwin
# City not found. Skipping...
# Processing Record 17 of Set 8 | paciran
# Processing Record 18 of Set 8 | tipperary
# Processing Record 19 of Set 8 | vilcun
# Processing Record 20 of Set 8 | ilinskiy
# Processing Record 21 of Set 8 | severodvinsk
# Processing Record 22 of Set 8 | huarmey
# Processing Record 23 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 8 | jiayuguan
# Processing Record 25 of Set 8 | aswan
# Processing Record 26 of Set 8 | yumen
# Processing Record 27 of Set 8 | popondetta
# Processing Record 28 of Set 8 | port moresby
# Processing Record 29 of Set 8 | deputatskiy
# Processing Record 30 of Set 8 | pisco
# Processing Record 31 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 32 of Set 8 | kysyl-syr
# Processing Record 33 of Set 8 | ziro
# Processing Record 34 of Set 8 | atambua
# Processing Record 35 of Set 8 | ambulu
# Processing Record 36 of Set 8 | auki
# Processing Record 37 of Set 8 | pacific grove
# Processing Record 38 of Set 8 | saint-augustin
# Processing Record 39 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 8 | torit
# Processing Record 42 of Set 8 | kruisfontein
# Processing Record 43 of Set 8 | virginia beach
# Processing Record 44 of Set 8 | ville-marie
# Processing Record 45 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 8 | harper
# Processing Record 48 of Set 8 | barabash
# Processing Record 49 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 8 | berbera
# Processing Record 1 of Set 9 | lantawan
# Processing Record 2 of Set 9 | eydhafushi
# Processing Record 3 of Set 9 | casablanca
# Processing Record 4 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 9 | mehamn
# Processing Record 6 of Set 9 | plouzane
# Processing Record 7 of Set 9 | calvinia
# Processing Record 8 of Set 9 | los llanos de aridane
# Processing Record 9 of Set 9 | griffith
# Processing Record 10 of Set 9 | salciile
# Processing Record 11 of Set 9 | oussouye
# Processing Record 12 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 13 of Set 9 | sobolevo
# Processing Record 14 of Set 9 | paraiso
# Processing Record 15 of Set 9 | petatlan
# Processing Record 16 of Set 9 | greenwood
# Processing Record 17 of Set 9 | pemba
# Processing Record 18 of Set 9 | paita
# Processing Record 19 of Set 9 | sisophon
# Processing Record 20 of Set 9 | muscatine
# Processing Record 21 of Set 9 | honningsvag
# Processing Record 22 of Set 9 | kavieng
# Processing Record 23 of Set 9 | progreso
# Processing Record 24 of Set 9 | baijiantan
# Processing Record 25 of Set 9 | egvekinot
# Processing Record 26 of Set 9 | iqaluit
# Processing Record 27 of Set 9 | colares
# Processing Record 28 of Set 9 | nara
# Processing Record 29 of Set 9 | guantanamo
# Processing Record 30 of Set 9 | da nang
# Processing Record 31 of Set 9 | lac du bonnet
# Processing Record 32 of Set 9 | mattru
# Processing Record 33 of Set 9 | whitehorse
# Processing Record 34 of Set 9 | oeiras
# Processing Record 35 of Set 9 | aguas formosas
# Processing Record 36 of Set 9 | shahr-e kord
# Processing Record 37 of Set 9 | hirara
# Processing Record 38 of Set 9 | sydney
# Processing Record 39 of Set 9 | bilibino
# Processing Record 40 of Set 9 | rio de jesus
# Processing Record 41 of Set 9 | alyangula
# Processing Record 42 of Set 9 | alice springs
# Processing Record 43 of Set 9 | leca da palmeira
# Processing Record 44 of Set 9 | vuktyl
# Processing Record 45 of Set 9 | itarema
# Processing Record 46 of Set 9 | moratuwa
# Processing Record 47 of Set 9 | vung tau
# Processing Record 48 of Set 9 | korla
# Processing Record 49 of Set 9 | ramanuj ganj
# Processing Record 50 of Set 9 | makat
# Processing Record 1 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 10 | cairns
# Processing Record 3 of Set 10 | akyab
# Processing Record 4 of Set 10 | vostok
# Processing Record 5 of Set 10 | monster
# Processing Record 6 of Set 10 | havoysund
# Processing Record 7 of Set 10 | nampula
# Processing Record 8 of Set 10 | ilo
# Processing Record 9 of Set 10 | ko samui
# Processing Record 10 of Set 10 | atagay
# Processing Record 11 of Set 10 | banjar
# Processing Record 12 of Set 10 | port lavaca
# Processing Record 13 of Set 10 | souillac
# Processing Record 14 of Set 10 | princeton
# Processing Record 15 of Set 10 | college
# Processing Record 16 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 17 of Set 10 | lagodekhi
# Processing Record 18 of Set 10 | jacmel
# Processing Record 19 of Set 10 | borama
# City not found. Skipping...
# Processing Record 20 of Set 10 | carlyle
# Processing Record 21 of Set 10 | altay
# Processing Record 22 of Set 10 | chunhuhub
# Processing Record 23 of Set 10 | felanitx
# Processing Record 24 of Set 10 | talaya
# Processing Record 25 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 10 | la ronge
# Processing Record 27 of Set 10 | aksu
# Processing Record 28 of Set 10 | kyrylivka
# Processing Record 29 of Set 10 | morondava
# Processing Record 30 of Set 10 | taylor
# Processing Record 31 of Set 10 | atamanovka
# Processing Record 32 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 33 of Set 10 | ahipara
# Processing Record 34 of Set 10 | brae
# Processing Record 35 of Set 10 | kharan
# Processing Record 36 of Set 10 | flin flon
# Processing Record 37 of Set 10 | laiagam
# City not found. Skipping...
# Processing Record 38 of Set 10 | la estancia
# Processing Record 39 of Set 10 | gorontalo
# Processing Record 40 of Set 10 | am timan
# Processing Record 41 of Set 10 | lavrentiya
# Processing Record 42 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 43 of Set 10 | narsaq
# Processing Record 44 of Set 10 | punta alta
# Processing Record 45 of Set 10 | balakhta
# Processing Record 46 of Set 10 | algiers
# Processing Record 47 of Set 10 | taltal
# Processing Record 48 of Set 10 | kenai
# Processing Record 49 of Set 10 | lakhdenpokhya
# Processing Record 50 of Set 10 | acapulco
# Processing Record 1 of Set 11 | wanning
# Processing Record 2 of Set 11 | warrnambool
# Processing Record 3 of Set 11 | bernay
# Processing Record 4 of Set 11 | brigantine
# Processing Record 5 of Set 11 | coquimbo
# Processing Record 6 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 7 of Set 11 | honiara
# Processing Record 8 of Set 11 | cap malheureux
# Processing Record 9 of Set 11 | taboga
# Processing Record 10 of Set 11 | dharchula
# Processing Record 11 of Set 11 | leeuwarden
# Processing Record 12 of Set 11 | tual
# Processing Record 13 of Set 11 | manica
# Processing Record 14 of Set 11 | luba
# Processing Record 15 of Set 11 | pangnirtung
# Processing Record 16 of Set 11 | taree
# Processing Record 17 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 11 | olafsvik
# Processing Record 19 of Set 11 | sligo
# Processing Record 20 of Set 11 | nieuw amsterdam
# Processing Record 21 of Set 11 | chulym
# Processing Record 22 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 23 of Set 11 | gimli
# Processing Record 24 of Set 11 | nambucca heads
# Processing Record 25 of Set 11 | vallenar
# Processing Record 26 of Set 11 | soyo
# Processing Record 27 of Set 11 | chimbote
# Processing Record 28 of Set 11 | gizo
# Processing Record 29 of Set 11 | mount isa
# Processing Record 30 of Set 11 | jieshi
# Processing Record 31 of Set 11 | north bend
# Processing Record 32 of Set 11 | aasiaat
# Processing Record 33 of Set 11 | murmashi
# Processing Record 34 of Set 11 | saint-francois
# Processing Record 35 of Set 11 | ntcheu
# Processing Record 36 of Set 11 | antalaha
# Processing Record 37 of Set 11 | along
# Processing Record 38 of Set 11 | ancud
# Processing Record 39 of Set 11 | jiaocheng
# Processing Record 40 of Set 11 | parana
# Processing Record 41 of Set 11 | severo-yeniseyskiy
# Processing Record 42 of Set 11 | lebu
# Processing Record 43 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 11 | storforshei
# Processing Record 45 of Set 11 | naze
# Processing Record 46 of Set 11 | yar-sale
# Processing Record 47 of Set 11 | port hedland
# Processing Record 48 of Set 11 | puerto suarez
# Processing Record 49 of Set 11 | uvinza
# Processing Record 50 of Set 11 | sierra vista
# Processing Record 1 of Set 12 | tessalit
# Processing Record 2 of Set 12 | oktyabrskiy
# Processing Record 3 of Set 12 | santa maria
# Processing Record 4 of Set 12 | wajima
# Processing Record 5 of Set 12 | jatiroto
# Processing Record 6 of Set 12 | cururupu
# Processing Record 7 of Set 12 | myaundzha
# Processing Record 8 of Set 12 | kishi
# Processing Record 9 of Set 12 | roma
# Processing Record 10 of Set 12 | dukat
# Processing Record 11 of Set 12 | abaete
# Processing Record 12 of Set 12 | zhuhai
# Processing Record 13 of Set 12 | carballo
# Processing Record 14 of Set 12 | leon
# Processing Record 15 of Set 12 | maniitsoq
# Processing Record 16 of Set 12 | kanpur
# Processing Record 17 of Set 12 | mahon
# Processing Record 18 of Set 12 | nouna
# Processing Record 19 of Set 12 | sabang
# Processing Record 20 of Set 12 | khao yoi
# Processing Record 21 of Set 12 | nemuro
# Processing Record 22 of Set 12 | puerto del rosario
# Processing Record 23 of Set 12 | tolaga bay
# Processing Record 24 of Set 12 | kousseri
# Processing Record 25 of Set 12 | sal rei
# Processing Record 26 of Set 12 | havre-saint-pierre
# Processing Record 27 of Set 12 | hvolsvollur
# Processing Record 28 of Set 12 | paucartambo
# City not found. Skipping...
# Processing Record 29 of Set 12 | ha tinh
# Processing Record 30 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 31 of Set 12 | flinders
# Processing Record 32 of Set 12 | varhaug
# Processing Record 33 of Set 12 | ukiah
# Processing Record 34 of Set 12 | portel
# Processing Record 35 of Set 12 | okhotsk
# Processing Record 36 of Set 12 | chiscani
# Processing Record 37 of Set 12 | denizli
# Processing Record 38 of Set 12 | willowmore
# Processing Record 39 of Set 12 | port-cartier
# Processing Record 40 of Set 12 | rio grande
# Processing Record 41 of Set 12 | vidim
# Processing Record 42 of Set 12 | sorong
# Processing Record 43 of Set 12 | mkushi
# Processing Record 44 of Set 12 | mosquera
# Processing Record 45 of Set 12 | kuito
# Processing Record 46 of Set 12 | seoul
# Processing Record 47 of Set 12 | bulgan
# Processing Record 48 of Set 12 | batemans bay
# Processing Record 49 of Set 12 | obluche
# City not found. Skipping...
# Processing Record 50 of Set 12 | soest
# Processing Record 1 of Set 13 | beloha
# Processing Record 2 of Set 13 | girona
# Processing Record 3 of Set 13 | jagraon
# Processing Record 4 of Set 13 | moose factory
# Processing Record 5 of Set 13 | sikeston
# Processing Record 6 of Set 13 | tamayo
# Processing Record 7 of Set 13 | taloqan
# Processing Record 8 of Set 13 | inuvik
# Processing Record 9 of Set 13 | southbury
# Processing Record 10 of Set 13 | onalaska
# Processing Record 11 of Set 13 | cassilandia
# Processing Record 12 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 13 | moiyabana
# City not found. Skipping...
# Processing Record 14 of Set 13 | theunissen
# Processing Record 15 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 16 of Set 13 | xuddur
# Processing Record 17 of Set 13 | smithers
# Processing Record 18 of Set 13 | gazni
# City not found. Skipping...
# Processing Record 19 of Set 13 | tariba
# Processing Record 20 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 13 | ust-maya
# Processing Record 22 of Set 13 | darnah
# Processing Record 23 of Set 13 | rincon
# Processing Record 24 of Set 13 | sompeta
# Processing Record 25 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 13 | cravo norte
# Processing Record 27 of Set 13 | khorixas
# Processing Record 28 of Set 13 | abu kamal
# Processing Record 29 of Set 13 | salta
# Processing Record 30 of Set 13 | pareora
# Processing Record 31 of Set 13 | burica
# City not found. Skipping...
# Processing Record 32 of Set 13 | sorgun
# Processing Record 33 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 34 of Set 13 | biak
# Processing Record 35 of Set 13 | aras
# Processing Record 36 of Set 13 | hay river
# Processing Record 37 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 38 of Set 13 | turukhansk
# Processing Record 39 of Set 13 | lamu
# Processing Record 40 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 13 | yeppoon
# Processing Record 42 of Set 13 | san jose
# Processing Record 43 of Set 13 | chapais
# Processing Record 44 of Set 13 | russell
# Processing Record 45 of Set 13 | beringovskiy
# Processing Record 46 of Set 13 | petropavl
# Processing Record 47 of Set 13 | udomlya
# Processing Record 48 of Set 13 | ferrol
# Processing Record 49 of Set 13 | gananoque
# Processing Record 50 of Set 13 | ulladulla
# Processing Record 1 of Set 14 | padang
# Processing Record 2 of Set 14 | noumea
# Processing Record 3 of Set 14 | assiniboia
# Processing Record 4 of Set 14 | laredo
# Processing Record 5 of Set 14 | yabelo
# Processing Record 6 of Set 14 | pechenga
# Processing Record 7 of Set 14 | barreirinha
# Processing Record 8 of Set 14 | mamallapuram
# Processing Record 9 of Set 14 | goderich
# Processing Record 10 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 11 of Set 14 | kon tum
# Processing Record 12 of Set 14 | tezu
# Processing Record 13 of Set 14 | tadine
# Processing Record 14 of Set 14 | praya
# Processing Record 15 of Set 14 | saumur
# Processing Record 16 of Set 14 | qasigiannguit
# Processing Record 17 of Set 14 | moranbah
# Processing Record 18 of Set 14 | inverell
# Processing Record 19 of Set 14 | tilichiki
# Processing Record 20 of Set 14 | kitimat
# Processing Record 21 of Set 14 | bjerringbro
# Processing Record 22 of Set 14 | urusha
# Processing Record 23 of Set 14 | angelokhorion
# City not found. Skipping...
# Processing Record 24 of Set 14 | mwinilunga
# Processing Record 25 of Set 14 | naryan-mar
# Processing Record 26 of Set 14 | hovd
# Processing Record 27 of Set 14 | santiago
# Processing Record 28 of Set 14 | kefalos
# Processing Record 29 of Set 14 | ligayan
# Processing Record 30 of Set 14 | manggar
# Processing Record 31 of Set 14 | middletown
# Processing Record 32 of Set 14 | asfi
# Processing Record 33 of Set 14 | teya
# Processing Record 34 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 14 | charagua
# Processing Record 36 of Set 14 | hobyo
# Processing Record 37 of Set 14 | ponta delgada
# Processing Record 38 of Set 14 | bazaliya
# Processing Record 39 of Set 14 | plattsburgh
# Processing Record 40 of Set 14 | huaiyuan
# Processing Record 41 of Set 14 | verkhoyansk
# Processing Record 42 of Set 14 | port blair
# Processing Record 43 of Set 14 | houma
# Processing Record 44 of Set 14 | camargo
# Processing Record 45 of Set 14 | xuchang
# Processing Record 46 of Set 14 | safford
# Processing Record 47 of Set 14 | izhmorskiy
# Processing Record 48 of Set 14 | barzas
# Processing Record 49 of Set 14 | batagay
# Processing Record 50 of Set 14 | mayumba
# Processing Record 1 of Set 15 | westport
# Processing Record 2 of Set 15 | chor
# Processing Record 3 of Set 15 | uyuni
# Processing Record 4 of Set 15 | tiguion
# Processing Record 5 of Set 15 | wairoa
# Processing Record 6 of Set 15 | shelburne
# Processing Record 7 of Set 15 | taoudenni
# Processing Record 8 of Set 15 | jinchang
# Processing Record 9 of Set 15 | kastornoye
# Processing Record 10 of Set 15 | firovo
# Processing Record 11 of Set 15 | bognor regis
# Processing Record 12 of Set 15 | muhos
# Processing Record 13 of Set 15 | mandali
# Processing Record 14 of Set 15 | hunchun
# Processing Record 15 of Set 15 | half moon bay
# Processing Record 16 of Set 15 | coos bay
# Processing Record 17 of Set 15 | calcutta
# Processing Record 18 of Set 15 | poya
# Processing Record 19 of Set 15 | sembabule
# Processing Record 20 of Set 15 | ixtapa
# Processing Record 21 of Set 15 | bulawayo
# Processing Record 22 of Set 15 | tacuati
# Processing Record 23 of Set 15 | surt
# Processing Record 24 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 25 of Set 15 | dryden
# Processing Record 26 of Set 15 | hwange
# Processing Record 27 of Set 15 | udachnyy
# Processing Record 28 of Set 15 | amapa
# Processing Record 29 of Set 15 | wilmington
# Processing Record 30 of Set 15 | mantua
# Processing Record 31 of Set 15 | sao felix do xingu
# Processing Record 32 of Set 15 | senges
# Processing Record 33 of Set 15 | micheweni
# Processing Record 34 of Set 15 | najran
# Processing Record 35 of Set 15 | acajutla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 668

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Haines Junction  60.7522 -137.5108     39.15        65         100
# 1      Mar Del Plata -38.0023  -57.5575     79.83        84           0
# 2         Butaritari   3.0707  172.7902     80.58        77          24
# 3             Kodiak  57.7900 -152.4072     44.33        70          34
# 4            Ushuaia -54.8000  -68.3000     42.46        61          75
# 5    Arraial Do Cabo -22.9661  -42.0278     84.16        65           0
# 6       Punta Arenas -53.1500  -70.9167     46.51        49          40
# 7         Codrington -38.2667  141.9667     51.39        82          98
# 8               Poum -20.2333  164.0167     75.74        73         100
# 9  Sao Joao Da Barra -21.6403  -41.0511     82.49        79          26
#
#    Wind Speed Country Current Description                 Date
# 0        6.91      CA     overcast clouds  2022-10-20 18:54:00
# 1       13.80      AR           clear sky  2022-10-20 18:54:00
# 2        9.08      KI          few clouds  2022-10-20 18:54:01
# 3       12.39      US    scattered clouds  2022-10-20 18:54:02
# 4       20.71      AR       broken clouds  2022-10-20 18:51:40
# 5       24.16      BR           clear sky  2022-10-20 18:54:02
# 6       29.93      CL    scattered clouds  2022-10-20 18:52:11
# 7        5.77      AU     overcast clouds  2022-10-20 18:54:03
# 8       16.44      NC     overcast clouds  2022-10-20 18:54:03
# 9       22.77      BR    scattered clouds  2022-10-20 18:54:04

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df.loc[:,["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df.loc[:,["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]

# Display sample data
city_data_df
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Haines Junction      CA  60.7522 -137.5108     39.15        65
# 1         Mar Del Plata      AR -38.0023  -57.5575     79.83        84
# 2            Butaritari      KI   3.0707  172.7902     80.58        77
# 3                Kodiak      US  57.7900 -152.4072     44.33        70
# 4               Ushuaia      AR -54.8000  -68.3000     42.46        61
# ..                  ...     ...      ...       ...       ...       ...
# 663  Sao Felix Do Xingu      BR  -6.6447  -51.9950     91.98        41
# 664              Senges      BR -24.1128  -49.4636     72.03        76
# 665           Micheweni      TZ  -4.9667   39.8333     75.52        79
# 666              Najran      SA  17.4924   44.1277     68.65        19
# 667            Acajutla      SV  13.5928  -89.8275     83.30        77
#
#      Cloudiness  Wind Speed Current Description
# 0           100        6.91     overcast clouds
# 1             0       13.80           clear sky
# 2            24        9.08          few clouds
# 3            34       12.39    scattered clouds
# 4            75       20.71       broken clouds
# ..          ...         ...                 ...
# 663          79        5.57       broken clouds
# 664          83        5.88       broken clouds
# 665         100       11.74     overcast clouds
# 666           8        2.42           clear sky
# 667          71        7.40       broken clouds
#
# [668 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City")
